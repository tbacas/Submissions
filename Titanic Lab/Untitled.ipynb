# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Lab: Titanic EDA
#
# This week was all about Pandas and plotting. At this point you should be chomping at the bit to get your hands dirty on a real-world dataset.
#
# For this lab, we're going to take a look at the Titanic manifest. We'll be exploring this data to see what we can learn regarding the survival rates of different groups of people.

# %% [markdown]
# ## Prework
# Fork and clone this repo. At the end of this lab, you'll submit a pull request using the `Titanic.ipynb` notebook to answer the questions below.

# %% [markdown]
# ## Step 1: Reading the data
#
# 1. Go to [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data)
# 2. If you scroll down the page a bit, you'll see a data dictionary explaining each of the columns. Take a minute to familiarize yourself with how the csv is structured.
# 4. Download the `train.csv` file into this project
# 3. Create an iPython notebook and load the csv into pandas.

# %%
df = pd.read_csv('train.csv')

df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ## Step 2: Cleaning the data
# 1. Create a bar chart showing how many missing values are in each column
# 2. Which column has the most `NaN` values? How many cells in that column are empty?
# 3. Delete all rows where `Embarked` is empty
# 4. Fill all empty cabins with **¯\\_(ツ)_/¯**
#
# Note: `NaN`, empty, and missing are synonymous.

# %%
df_temp =df.isnull().sum()
df_temp.plot.bar()

# %% [markdown]
# Cabin has the most NaN values at 687.

# %%
df['Embarked'] = df['Embarked'].dropna

# %%
#df['Cabin'] = df['Cabin'].replace('NaN',' ¯\(ツ)/¯')

df['Cabin'].fillna(' ¯\(ツ)/¯',inplace = True)

# %%
df['Age'].fillna(' empty',inplace = True)

# %% [markdown]
# ## Step 3: Feature extraction
# 1.  There are two columns that pertain to how many family members are on the boat for a given person. Create a new column called `FamilyCount` which will be the sum of those two columns.
# 2. Reverends have a special title in their name. Create a column called `IsReverend`: 1 if they're a preacher, 0 if they're not.
# 3. In order to feed our training data into a classification algorithm, we need to convert our categories into 1's and 0's using `pd.get_dummies`
#   - Create 3 columns: `Embarked_C`, `Embarked_Q` and `Embarked_S`. These columns will have 1's and 0's that correspond to the `C`, `Q` and `S` values in the `Embarked` column
#   - Do the same thing for `Sex`
#   - BONUS: Extract the title from everyone's name and create dummy columns

# %%
df_split = pd.get_dummies(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     344             try:
# --> 345                 codes, categories = factorize(values, sort=True)
#     346             except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     629                                            size_hint=size_hint,
# --> 630                                            na_value=na_value)
#     631
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     475     labels = table.get_labels(values, uniques, 0, na_sentinel,
# --> 476                               na_value=na_value)
#     477
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1488         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1489                         ' hashed'.format(self.__class__.__name__))
#    1490
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5ab72a382caa> in <module>()
# ----> 1 df_split = pd.get_dummies(df)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     878             dummy = _get_dummies_1d(col[1], prefix=pre, prefix_sep=sep,
#     879                                     dummy_na=dummy_na, sparse=sparse,
# --> 880                                     drop_first=drop_first, dtype=dtype)
#     881             with_dummies.append(dummy)
#     882         result = concat(with_dummies, axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     892                     sparse=False, drop_first=False, dtype=None):
#     893     # Series avoids inconsistent NaN handling
# --> 894     codes, levels = _factorize_from_iterable(Series(data))
#     895
#     896     if dtype is None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in _factorize_from_iterable(values)
#    2513         codes = values.codes
#    2514     else:
# -> 2515         cat = Categorical(values, ordered=True)
#    2516         categories = cat.categories
#    2517         codes = cat.codes
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     345                 codes, categories = factorize(values, sort=True)
#     346             except TypeError:
# --> 347                 codes, categories = factorize(values, sort=False)
#     348                 if dtype.ordered:
#     349                     # raise, as we don't have a sortable data structure and so
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     628                                            na_sentinel=na_sentinel,
#     629                                            size_hint=size_hint,
# --> 630                                            na_value=na_value)
#     631
#     632     if sort and len(uniques) > 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     474     uniques = vec_klass()
#     475     labels = table.get_labels(values, uniques, 0, na_sentinel,
# --> 476                               na_value=na_value)
#     477
#     478     labels = _ensure_platform_int(labels)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1487     def __hash__(self):
#    1488         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1489                         ' hashed'.format(self.__class__.__name__))
#    1490
#    1491     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %% [markdown]
# ## Step 4: Exploratory analysis
# 1. What was the survival rate overall?
# 2. Which gender fared the worst? What was their survival rate?
# 3. What was the survival rate for each `Pclass`?
# 4. Did any reverends survive? How many?
# 5. What is the survival rate for cabins marked **¯\\_(ツ)_/¯**
# 6. What is the survival rate for people whose `Age` is empty?
# 7. What is the survival rate for each port of embarkation?
# 8. What is the survival rate for children (under 12) in each `Pclass`?
# 9. Did the captain of the ship survive? Is he on the list?
# 10. Of all the people that died, who had the most expensive ticket? How much did it cost?
# 11. Does having family on the boat help or hurt your chances of survival?

# %%
for each in df['Survived'].value_counts():
    t= each/890
    print(t)
# Out:
# 0.6168539325842697
# 0.3842696629213483

# %%
df.groupby(["Sex","Survived"]).size()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# dtype: int64

# %%
df.groupby(["Pclass","Survived"]).size()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %%
titanic = df.drop(['Age', 'Parch', 'Ticket', 'Fare', 'Cabin'], axis=1)

# %%
titanic['Title'] = titanic.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip())
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  \
# 0                              Braund, Mr. Owen Harris    male      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1
# 2                               Heikkinen, Miss. Laina  female      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1
# 4                             Allen, Mr. William Henry    male      0
# 5                                     Moran, Mr. James    male      0
# 6                              McCarthy, Mr. Timothy J    male      0
# 7                       Palsson, Master. Gosta Leonard    male      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female      1
# 10                     Sandstrom, Miss. Marguerite Rut  female      1
# 11                            Bonnell, Miss. Elizabeth  female      0
# 12                      Saundercock, Mr. William Henry    male      0
# 13                         Andersson, Mr. Anders Johan    male      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female      0
# 16                                Rice, Master. Eugene    male      4
# 17                        Williams, Mr. Charles Eugene    male      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female      1
# 19                             Masselmani, Mrs. Fatima  female      0
# 20                                Fynney, Mr. Joseph J    male      0
# 21                               Beesley, Mr. Lawrence    male      0
# 22                         McGowan, Miss. Anna "Annie"  female      0
# 23                        Sloper, Mr. William Thompson    male      0
# 24                       Palsson, Miss. Torborg Danira  female      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female      1
# 26                             Emir, Mr. Farred Chehab    male      0
# 27                      Fortune, Mr. Charles Alexander    male      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female      0
# 29                                 Todoroff, Mr. Lalio    male      0
# ..                                                 ...     ...    ...
# 861                        Giles, Mr. Frederick Edward    male      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female      8
# 864                             Gill, Mr. John William    male      0
# 865                           Bystrom, Mrs. (Karolina)  female      0
# 866                       Duran y More, Miss. Asuncion  female      1
# 867               Roebling, Mr. Washington Augustus II    male      0
# 868                        van Melkebeke, Mr. Philemon    male      0
# 869                    Johnson, Master. Harold Theodor    male      1
# 870                                  Balkic, Mr. Cerin    male      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female      1
# 872                           Carlsson, Mr. Frans Olof    male      0
# 873                        Vander Cruyssen, Mr. Victor    male      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female      0
# 876                      Gustafsson, Mr. Alfred Ossian    male      0
# 877                               Petroff, Mr. Nedelio    male      0
# 878                                 Laleff, Mr. Kristo    male      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female      0
# 881                                 Markun, Mr. Johann    male      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female      0
# 883                      Banfield, Mr. Frederick James    male      0
# 884                             Sutehall, Mr. Henry Jr    male      0
# 885               Rice, Mrs. William (Margaret Norton)  female      0
# 886                              Montvila, Rev. Juozas    male      0
# 887                       Graham, Miss. Margaret Edith  female      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      1
# 889                              Behr, Mr. Karl Howell    male      0
# 890                                Dooley, Mr. Patrick    male      0
#
#     Embarked   Title
# 0          S      Mr
# 1          C     Mrs
# 2          S    Miss
# 3          S     Mrs
# 4          S      Mr
# 5          Q      Mr
# 6          S      Mr
# 7          S  Master
# 8          S     Mrs
# 9          C     Mrs
# 10         S    Miss
# 11         S    Miss
# 12         S      Mr
# 13         S      Mr
# 14         S    Miss
# 15         S     Mrs
# 16         Q  Master
# 17         S      Mr
# 18         S     Mrs
# 19         C     Mrs
# 20         S      Mr
# 21         S      Mr
# 22         Q    Miss
# 23         S      Mr
# 24         S    Miss
# 25         S     Mrs
# 26         C      Mr
# 27         S      Mr
# 28         Q    Miss
# 29         S      Mr
# ..       ...     ...
# 861        S      Mr
# 862        S     Mrs
# 863        S    Miss
# 864        S      Mr
# 865        S     Mrs
# 866        C    Miss
# 867        S      Mr
# 868        S      Mr
# 869        S  Master
# 870        S      Mr
# 871        S     Mrs
# 872        S      Mr
# 873        S      Mr
# 874        C     Mrs
# 875        C    Miss
# 876        S      Mr
# 877        S      Mr
# 878        S      Mr
# 879        C     Mrs
# 880        S     Mrs
# 881        S      Mr
# 882        S    Miss
# 883        S      Mr
# 884        S      Mr
# 885        Q     Mrs
# 886        S     Rev
# 887        S    Miss
# 888        S    Miss
# 889        C      Mr
# 890        Q      Mr
#
# [891 rows x 8 columns]

# %%
titanic.groupby(["Title","Survived"]).size()
# Out:
# Title         Survived
# Capt          0             1
# Col           0             1
#               1             1
# Don           0             1
# Dr            0             4
#               1             3
# Jonkheer      0             1
# Lady          1             1
# Major         0             1
#               1             1
# Master        0            17
#               1            23
# Miss          0            55
#               1           127
# Mlle          1             2
# Mme           1             1
# Mr            0           436
#               1            81
# Mrs           0            26
#               1            99
# Ms            1             1
# Rev           0             6
# Sir           1             1
# the Countess  1             1
# dtype: int64

# %%
df.groupby(['Cabin','Survived']).size()
# Out:
# Cabin     Survived
#  ¯\(ツ)/¯  0           481
#           1           206
# A10       0             1
# A14       0             1
# A16       1             1
# A19       0             1
# A20       1             1
# A23       1             1
# A24       0             1
# A26       1             1
# A31       1             1
# A32       0             1
# A34       1             1
# A36       0             1
# A5        0             1
# A6        1             1
# A7        0             1
# B101      1             1
# B102      0             1
# B18       1             2
# B19       0             1
# B20       1             2
# B22       0             1
#           1             1
# B28       1             2
# B3        1             1
# B30       0             1
# B35       1             2
# B37       0             1
# B38       0             1
#                      ...
# E25       1             2
# E31       0             1
# E33       1             2
# E34       1             1
# E36       1             1
# E38       0             1
# E40       1             1
# E44       0             1
#           1             1
# E46       0             1
# E49       1             1
# E50       1             1
# E58       0             1
# E63       0             1
# E67       0             1
#           1             1
# E68       1             1
# E77       0             1
# E8        1             2
# F E69     1             1
# F G63     0             1
# F G73     0             2
# F2        0             1
#           1             2
# F33       1             3
# F38       0             1
# F4        1             2
# G6        0             2
#           1             2
# T         0             1
# Length: 165, dtype: int64

# %%
df.groupby(['Age','Survived']).size()
# Out:
# Age    Survived
# 0.42   1           1
# 0.67   1           1
# 0.75   1           2
# 0.83   1           2
# 0.92   1           1
# 1.00   0           2
#        1           5
# 2.00   0           7
#        1           3
# 3.00   0           1
#        1           5
# 4.00   0           3
#        1           7
# 5.00   1           4
# 6.00   0           1
#        1           2
# 7.00   0           2
#        1           1
# 8.00   0           2
#        1           2
# 9.00   0           6
#        1           2
# 10.00  0           2
# 11.00  0           3
#        1           1
# 12.00  1           1
# 13.00  1           2
# 14.00  0           3
#        1           3
# 14.50  0           1
#                   ..
# 51.00  0           5
#        1           2
# 52.00  0           3
#        1           3
# 53.00  1           1
# 54.00  0           5
#        1           3
# 55.00  0           1
#        1           1
# 55.50  0           1
# 56.00  0           2
#        1           2
# 57.00  0           2
# 58.00  0           2
#        1           3
# 59.00  0           2
# 60.00  0           2
#        1           2
# 61.00  0           3
# 62.00  0           2
#        1           2
# 63.00  1           2
# 64.00  0           2
# 65.00  0           3
# 66.00  0           1
# 70.00  0           2
# 70.50  0           1
# 71.00  0           2
# 74.00  0           1
# 80.00  1           1
# Length: 142, dtype: int64

# %%
df.groupby(['Embarked','Survived']).size()
# Out:
# Embarked  Survived
# C         0            75
#           1            93
# Q         0            47
#           1            30
# S         0           427
#           1           217
# dtype: int64

# %%
age_temp = df.query('Age < 12')
age_temp.groupby(['Pclass','Survived']).size()
# Out:
# Pclass  Survived
# 1       0            1
#         1            3
# 2       1           17
# 3       0           28
#         1           19
# dtype: int64

# %%
ticket_temp = df.query('Survived == 0')
ticket_temp['Fare'].sort_values(ascending= False)
# Out:
# 27     263.0000
# 438    263.0000
# 118    247.5208
# 557    227.5250
# 527    221.7792
# 377    211.5000
# 332    153.4625
# 498    151.5500
# 297    151.5500
# 373    135.6333
# 659    113.2750
# 698    110.8833
# 505    108.9000
# 544    106.4250
# 245     90.0000
# 62      83.4750
# 34      82.1708
# 262     79.6500
# 139     79.2000
# 789     79.2000
# 741     78.8500
# 102     77.2875
# 124     77.2875
# 120     73.5000
# 665     73.5000
# 655     73.5000
# 72      73.5000
# 385     73.5000
# 745     71.0000
# 846     69.5500
#          ...
# 131      7.0500
# 465      7.0500
# 784      7.0500
# 477      7.0458
# 129      6.9750
# 825      6.9500
# 411      6.8583
# 654      6.7500
# 143      6.7500
# 371      6.4958
# 202      6.4958
# 818      6.4500
# 843      6.4375
# 326      6.2375
# 872      5.0000
# 378      4.0125
# 413      0.0000
# 822      0.0000
# 674      0.0000
# 633      0.0000
# 481      0.0000
# 815      0.0000
# 302      0.0000
# 806      0.0000
# 466      0.0000
# 732      0.0000
# 597      0.0000
# 263      0.0000
# 277      0.0000
# 179      0.0000
# Name: Fare, Length: 549, dtype: float64

# %%
titanic['Last'] = df.Name.apply(lambda name: name.split(',')[0].split('.')[0].strip())
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  \
# 0                              Braund, Mr. Owen Harris    male      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1
# 2                               Heikkinen, Miss. Laina  female      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1
# 4                             Allen, Mr. William Henry    male      0
# 5                                     Moran, Mr. James    male      0
# 6                              McCarthy, Mr. Timothy J    male      0
# 7                       Palsson, Master. Gosta Leonard    male      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female      1
# 10                     Sandstrom, Miss. Marguerite Rut  female      1
# 11                            Bonnell, Miss. Elizabeth  female      0
# 12                      Saundercock, Mr. William Henry    male      0
# 13                         Andersson, Mr. Anders Johan    male      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female      0
# 16                                Rice, Master. Eugene    male      4
# 17                        Williams, Mr. Charles Eugene    male      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female      1
# 19                             Masselmani, Mrs. Fatima  female      0
# 20                                Fynney, Mr. Joseph J    male      0
# 21                               Beesley, Mr. Lawrence    male      0
# 22                         McGowan, Miss. Anna "Annie"  female      0
# 23                        Sloper, Mr. William Thompson    male      0
# 24                       Palsson, Miss. Torborg Danira  female      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female      1
# 26                             Emir, Mr. Farred Chehab    male      0
# 27                      Fortune, Mr. Charles Alexander    male      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female      0
# 29                                 Todoroff, Mr. Lalio    male      0
# ..                                                 ...     ...    ...
# 861                        Giles, Mr. Frederick Edward    male      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female      8
# 864                             Gill, Mr. John William    male      0
# 865                           Bystrom, Mrs. (Karolina)  female      0
# 866                       Duran y More, Miss. Asuncion  female      1
# 867               Roebling, Mr. Washington Augustus II    male      0
# 868                        van Melkebeke, Mr. Philemon    male      0
# 869                    Johnson, Master. Harold Theodor    male      1
# 870                                  Balkic, Mr. Cerin    male      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female      1
# 872                           Carlsson, Mr. Frans Olof    male      0
# 873                        Vander Cruyssen, Mr. Victor    male      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female      0
# 876                      Gustafsson, Mr. Alfred Ossian    male      0
# 877                               Petroff, Mr. Nedelio    male      0
# 878                                 Laleff, Mr. Kristo    male      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female      0
# 881                                 Markun, Mr. Johann    male      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female      0
# 883                      Banfield, Mr. Frederick James    male      0
# 884                             Sutehall, Mr. Henry Jr    male      0
# 885               Rice, Mrs. William (Margaret Norton)  female      0
# 886                              Montvila, Rev. Juozas    male      0
# 887                       Graham, Miss. Margaret Edith  female      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      1
# 889                              Behr, Mr. Karl Howell    male      0
# 890                                Dooley, Mr. Patrick    male      0
#
#     Embarked   Title             Last
# 0          S      Mr           Braund
# 1          C     Mrs          Cumings
# 2          S    Miss        Heikkinen
# 3          S     Mrs         Futrelle
# 4          S      Mr            Allen
# 5          Q      Mr            Moran
# 6          S      Mr         McCarthy
# 7          S  Master          Palsson
# 8          S     Mrs          Johnson
# 9          C     Mrs           Nasser
# 10         S    Miss        Sandstrom
# 11         S    Miss          Bonnell
# 12         S      Mr      Saundercock
# 13         S      Mr        Andersson
# 14         S    Miss          Vestrom
# 15         S     Mrs          Hewlett
# 16         Q  Master             Rice
# 17         S      Mr         Williams
# 18         S     Mrs    Vander Planke
# 19         C     Mrs       Masselmani
# 20         S      Mr           Fynney
# 21         S      Mr          Beesley
# 22         Q    Miss          McGowan
# 23         S      Mr           Sloper
# 24         S    Miss          Palsson
# 25         S     Mrs          Asplund
# 26         C      Mr             Emir
# 27         S      Mr          Fortune
# 28         Q    Miss          O'Dwyer
# 29         S      Mr         Todoroff
# ..       ...     ...              ...
# 861        S      Mr            Giles
# 862        S     Mrs            Swift
# 863        S    Miss             Sage
# 864        S      Mr             Gill
# 865        S     Mrs          Bystrom
# 866        C    Miss     Duran y More
# 867        S      Mr         Roebling
# 868        S      Mr    van Melkebeke
# 869        S  Master          Johnson
# 870        S      Mr           Balkic
# 871        S     Mrs         Beckwith
# 872        S      Mr         Carlsson
# 873        S      Mr  Vander Cruyssen
# 874        C     Mrs          Abelson
# 875        C    Miss            Najib
# 876        S      Mr       Gustafsson
# 877        S      Mr          Petroff
# 878        S      Mr           Laleff
# 879        C     Mrs           Potter
# 880        S     Mrs          Shelley
# 881        S      Mr           Markun
# 882        S    Miss         Dahlberg
# 883        S      Mr         Banfield
# 884        S      Mr         Sutehall
# 885        Q     Mrs             Rice
# 886        S     Rev         Montvila
# 887        S    Miss           Graham
# 888        S    Miss         Johnston
# 889        C      Mr             Behr
# 890        Q      Mr           Dooley
#
# [891 rows x 9 columns]

# %%
family = titanic.query('SibSp > 1')
family_count = family['Survived'].value_counts()

family_count[0]/(family_count[0]+family_count[1])
# Out:
# 0.7297297297297297

# %%
no_family = titanic.query('SibSp < 1')
no_family_count = no_family['Survived'].value_counts()

(no_family_count[0]/(no_family_count[0]+no_family_count[1]))*100
# Out:
# 65.46052631578947

# %% [markdown]
# ## Step 5: Plotting
# Using Matplotlib and Seaborn, create several charts showing the survival rates of different groups of people. It's fine if a handful of charts are basic (Gender, Age, etc), but what we're really looking for is something beneath the surface.

# %%
class_survival_plot = df.groupby('Pclass')['Survived'].mean()
plt1 = class_survival_plot.plot.bar(title='Survival Rate by Class')
plt1

# %%
sex_survival_plot = df.groupby('Sex')['Survived'].mean()
plt2 = sex_survival_plot.plot.bar(title='Survival Rate by Sex', sharey = True)
plt2

# %%
title_survival_plot = titanic.groupby('Title')['Survived'].mean()
plt3 = title_survival_plot.plot.bar(title='Survival Rate by Sex', sharey = True)
plt3

# %%
title_survival_plot = df.groupby('Sex')['Fare'].mean()
plt4 = title_survival_plot.plot.bar(title='Fare by Sex', sharey = True)
plt4
