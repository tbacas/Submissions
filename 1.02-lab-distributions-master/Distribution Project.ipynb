# %% [markdown]
# # 1.03 Distributions Lab
#
# **NOTE**: Double-click on the cells that say "Type _Markdown_ and LaTeX: $\alpha^2$" to open a Markdown cell in which you can enter text without needing to put comments in code cells!

# %% [markdown]
# #### 1. Define distribution.

# %% [markdown]
# a set of values of a variable and how frequently they occur

# %% [markdown]
# #### 2. When summarizing the distribution of a variable, what are the three aspects of distributions we want to make sure we summarize?

# %% [markdown]
# Spread of the Distribution, Slope of the Distribution and Scale of the Distribution.

# %% [markdown]
# #### 3. What is a Bernoulli random variable?

# %% [markdown]
# Either success or failure

# %% [markdown]
# #### 4. What is the relationship between the Bernoulli and Binomial distributions?

# %% [markdown]
# a Bernoulli distribution contains only 1 instance of a binary variables (or success/failure).  A binomial distribution contains a set amount of instances of the same binary variables.

# %% [markdown]
# #### 5. What is the relationship between the Binomial and Poisson distributions?

# %% [markdown]
# Similar to the binomial distribution, the Poisson distribution puts that to the extreme by counting the amount of binary results in a set amount of time (fixed amount of time, not set amount of trials).

# %% [markdown]
# #### 6. What is the relationship between the Exponential and Geometric distributions?

# %% [markdown]
# A Geometric distribution measures the number of trials until one success unlike an exponential distribution which counts the number of successses in a set amount of time. Similar to a Poisson distribution but with a continuous variable as opposed to a discrete variable.

# %% [markdown]
# #### 7. Let's walk through the Central Limit Theorem.
#
# a) Let's create a population of 10,000 observations from a Normal distribution with mean 500 and standard deviation 100. Save this as `population`. Before this step, however, set your seed to 45 using using `random.seed(45)`.

# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import imp

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

np.random.seed(45)

# %%
population = np.random.normal(500,100,10000)

# %%
plt.hist(population,100)
# Out:
# (array([  1.,   0.,   2.,   0.,   3.,   2.,   3.,   6.,   5.,   7.,   8.,
#          15.,  11.,  12.,  11.,  22.,  25.,  30.,  34.,  36.,  51.,  44.,
#          62.,  62.,  71.,  78.,  93., 105., 122., 114., 121., 139., 152.,
#         176., 204., 202., 176., 195., 237., 256., 261., 297., 263., 274.,
#         305., 294., 303., 297., 262., 269., 294., 286., 247., 262., 252.,
#         235., 228., 213., 231., 176., 201., 176., 130., 165., 158., 120.,
#         107.,  93.,  88.,  66.,  88.,  58.,  69.,  67.,  37.,  36.,  33.,
#          29.,  26.,  19.,  12.,  12.,  16.,  13.,   9.,   7.,   5.,   3.,
#           2.,   2.,   1.,   2.,   1.,   2.,   1.,   1.,   1.,   1.,   0.,
#           1.]), array([157.53726786, 164.73425896, 171.93125005, 179.12824115,
#         186.32523225, 193.52222335, 200.71921444, 207.91620554,
#         215.11319664, 222.31018774, 229.50717884, 236.70416993,
#         243.90116103, 251.09815213, 258.29514323, 265.49213433,
#         272.68912542, 279.88611652, 287.08310762, 294.28009872,
#         301.47708982, 308.67408091, 315.87107201, 323.06806311,
#         330.26505421, 337.4620453 , 344.6590364 , 351.8560275 ,
#         359.0530186 , 366.2500097 , 373.44700079, 380.64399189,
#         387.84098299, 395.03797409, 402.23496519, 409.43195628,
#         416.62894738, 423.82593848, 431.02292958, 438.21992068,
#         445.41691177, 452.61390287, 459.81089397, 467.00788507,
#         474.20487616, 481.40186726, 488.59885836, 495.79584946,
#         502.99284056, 510.18983165, 517.38682275, 524.58381385,
#         531.78080495, 538.97779605, 546.17478714, 553.37177824,
#         560.56876934, 567.76576044, 574.96275154, 582.15974263,
#         589.35673373, 596.55372483, 603.75071593, 610.94770702,
#         618.14469812, 625.34168922, 632.53868032, 639.73567142,
#         646.93266251, 654.12965361, 661.32664471, 668.52363581,
#         675.72062691, 682.917618  , 690.1146091 , 697.3116002 ,
#         704.5085913 , 711.7055824 , 718.90257349, 726.09956459,
#         733.29655569, 740.49354679, 747.69053789, 754.88752898,
#         762.08452008, 769.28151118, 776.47850228, 783.67549337,
#         790.87248447, 798.06947557, 805.26646667, 812.46345777,
#         819.66044886, 826.85743996, 834.05443106, 841.25142216,
#         848.44841326, 855.64540435, 862.84239545, 870.03938655,
#         877.23637765]), <a list of 100 Patch objects>)

# %% [markdown]
# b) Generate 1,000 random samples of size 5 from `population`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `norm_samples_5`.

# %%
def new_experiment(population, sample_size, num_of_runs):
    means =[]
    for i in range (1,num_of_runs):
        temp = np.random.choice(population,sample_size)
        means.append(temp.mean())
    return means

# %%
norm_samples_5 = new_experiment(population,5,1000)

# %% [markdown]
# We simulated the sampling distribution of $\bar{X}$ when we took the mean of 1,000 samples from the population. This isn't exactly what the sampling distribution of $\bar{X}$ is, but it's close enough for our purposes!
#
# (In general, we'd actually take every possible sample of size 5 from our population, but that can get really complicated.)

# %% [markdown]
# c) Plot `norm_samples_5` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(norm_samples_5,25,kde=True)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# d) How would you describe the shape of the distribution from c)?

# %% [markdown]
# distribution "c" is similar to a normal distribution with a rather high peak near the mean.

# %% [markdown]
# e) Generate 1,000 random samples of size 50 from `population`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `norm_samples_50`.

# %%
norm_samples_50 = new_experiment(population,50,1000)

# %% [markdown]
# f) Plot `norm_samples_50` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(norm_samples_50,25,kde=True)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# g) How would you describe the shape of the distribution from f), relative to the distribution you generated for part c)?

# %% [markdown]
# Not suprisingly, the distribution moves closer to a normal distribution as the amount of experiments increases.

# %% [markdown]
# h) Run this command:
#
# ```python
# random.seed(46)
# population_2 = [np.random.choice([np.random.poisson(2),np.random.poisson(10),np.random.exponential(5)]) for i in range(10000)]
#
# ```

# %%
np.random.seed(46)
population_2 = [np.random.choice([np.random.poisson(2),np.random.poisson(10),np.random.exponential(5)]) for i in range(10000)]

# %%
plt.hist(population_2)
# Out:
# (array([4648., 1635., 1930., 1159.,  490.,   92.,   22.,   14.,    5.,
#            5.]),
#  array([ 0.        ,  3.47713463,  6.95426926, 10.43140389, 13.90853852,
#         17.38567316, 20.86280779, 24.33994242, 27.81707705, 31.29421168,
#         34.77134631]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# i) What is the command in h) doing?

# %% [markdown]
# Makes a non-normal exponential population.

# %% [markdown]
# j) Is the population created in `population_2` Normally distributed? How do you know?

# %% [markdown]
# It is not normal. As the above plot shows the population is skewed to the Right showing most datapoints falling between 0 - 5 and fewer larger numbers.

# %% [markdown]
# k) Generate 1,000 random samples of size 5 from `population_2`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `poiexp_samples_5`.

# %%
poiexp_samples_5 = new_experiment(population_2,5,1000)

# %% [markdown]
# l) Plot `poiexp_samples_5` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(poiexp_samples_5,25,kde=True)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# m) How would you describe the shape of the distribution from l)?

# %% [markdown]
# a Normal distribution.

# %% [markdown]
# n) Generate 1,000 random samples of size 50 from `population_2`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `poiexp_samples_50`.

# %%
poiexp_samples_50 = new_experiment(population_2,50,1000)

# %% [markdown]
# o) Plot `poiexp_samples_50` with a kernel density estimate using seaborn.distplot.

# %%
sns.distplot(poiexp_samples_50,25,kde=True)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# p) How would you describe the shape of the distribution from o)?

# %% [markdown]
# a normal distribution.

# %% [markdown]
# **You just observed the Central Limit Theorem. Let's make this a bit more explicit.**
#
# q) When our original data came from a Normal distribution (`population`) and we looked at the sampling distribution of $\bar{X}$ for $n=5$ (`norm_samples_5`), what was the shape of the sampling distribution of $\bar{X}$?

# %%
sns.distplot(norm_samples_5)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# r) When our original data came from a Normal distribution (`population`) and we looked at the sampling distribution of $\bar{X}$ for $n=50$ (`norm_samples_50`), what was the shape of the sampling distribution of $\bar{X}$?

# %%
sns.distplot(norm_samples_50)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# s) So, if our original population is a Normal distribution, what will the sampling distribution be shaped like - regardless of sample size?

# %% [markdown]
# It will be a normal distribution.

# %% [markdown]
# t) When our original data came from a non-Normal distribution (`population_2`) and we looked at the sampling distribution of $\bar{X}$ for $n=5$ (`poiexp_samples_5`), what was the shape of the sampling distribution of $\bar{X}$?

# %%
sns.distplot(poiexp_samples_5)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# u) When our original data came from a non-Normal distribution (`population_2`) and we looked at the sampling distribution of $\bar{X}$ for $n=50$ (`poiexp_samples_50`), what was the shape of the sampling distribution of $\bar{X}$?

# %%
sns.distplot(poiexp_samples_50)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# v) So, if our original population is not a Normal distribution, what will the sampling distribution be shaped like when $n$ is small (like 5)?

# %% [markdown]
# It will be scattered and somewhat random, as the sample is small.

# %% [markdown]
# w) So, if our original population is not a Normal distribution, what will the sampling distribution be shaped like when $n$ is large (like 50)?

# %% [markdown]
# A larger sample will make the distribution closer to a Normal Distribution.

# %% [markdown]
# x) When you sample from a non-Normal distribution, what happens to our sampling distribution of $\bar{X}$ as we increase $n$?

# %% [markdown]
# It becomes closer to a normal distribution.

# %% [markdown]
# BONUS: If you're so inclined, repeat steps k and l for sample size $n=10, 20, 30, 50, 100$ to look at this phenomenon more closely! You could write a loop to do this.
