# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import sklearn.linear_model as linear_model
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import FormatStrFormatter
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
#null=df.isnull().sum()
#null.sort_values(ascending = False)

# %%
numeric = df._get_numeric_data
num_cols = df._get_numeric_data().columns
num_cols
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area',
#        'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area',
#        'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath',
#        'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Wood Deck SF',
#        'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch',
#        'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'SalePrice'],
#       dtype='object')

# %%
df= pd.get_dummies(df,columns =['Overall Qual'])

# %%
test = pd.get_dummies(test,columns =['Overall Qual'])

# %%
df['Total Bsmt SF'].fillna(0,inplace = True)
test['Total Bsmt SF'].fillna(0,inplace = True)

# %%
target = df['SalePrice']

# %%
predictor_corr = df.corrwith(target)
predictor_corr.sort_values(ascending = False)
# Out:
# SalePrice          1.000000
# Gr Liv Area        0.697038
# Garage Area        0.650270
# Garage Cars        0.648220
# Total Bsmt SF      0.629303
# 1st Flr SF         0.618486
# Year Built         0.571849
# Year Remod/Add     0.550370
# Full Bath          0.537969
# Garage Yr Blt      0.533922
# Mas Vnr Area       0.512230
# TotRms AbvGrd      0.504014
# Fireplaces         0.471093
# Overall Qual_9     0.470399
# BsmtFin SF 1       0.423519
# Overall Qual_8     0.423016
# Lot Frontage       0.341842
# Open Porch SF      0.333476
# Wood Deck SF       0.326490
# Overall Qual_10    0.317078
# Lot Area           0.296566
# Bsmt Full Bath     0.283662
# Half Bath          0.283001
# 2nd Flr SF         0.248452
# Bsmt Unf SF        0.190210
# Overall Qual_7     0.142950
# Bedroom AbvGr      0.137067
# Screen Porch       0.134581
# 3Ssn Porch         0.048732
# Mo Sold            0.032735
# Pool Area          0.023106
# BsmtFin SF 2       0.016255
# Misc Val          -0.007375
# Yr Sold           -0.015203
# Low Qual Fin SF   -0.041594
# Bsmt Half Bath    -0.045328
# Id                -0.051398
# Overall Qual_1    -0.074054
# MS SubClass       -0.087335
# Overall Cond      -0.097019
# Overall Qual_2    -0.109243
# Kitchen AbvGr     -0.125444
# Overall Qual_6    -0.134179
# Enclosed Porch    -0.135656
# Overall Qual_3    -0.151379
# PID               -0.255052
# Overall Qual_4    -0.269722
# Overall Qual_5    -0.361012
# dtype: float64

# %%
df['Garage Cars'].fillna(0, inplace=True)
df['Garage Area'].fillna(0, inplace=True)
df['Total Bsmt SF'].fillna(0, inplace = True)

# %%
df['Garage Yr Blt'].
# Out:
#   File "<ipython-input-15-38004b286148>", line 1
#     df['Garage Yr Blt'].
#                         ^
# SyntaxError: invalid syntax

# %%
features = ['Year Built','Year Remod/Add', 'Overall Qual_2',
         'Overall Qual_3','Overall Qual_4','Overall Qual_5',
         'Overall Qual_6','Overall Qual_7','Overall Qual_8',
         'Overall Qual_9','Overall Qual_10','Gr Liv Area'
         ,'Total Bsmt SF','Garage Area','1st Flr SF', 'Full Bath','Fireplaces','TotRms AbvGrd']

# %%
sns.heatmap(df[features].corr())

# %%
X_test = test[features]

# %%
lm = linear_model.LinearRegression()
target = df['SalePrice']

X = df[features]
y = target


model = lm.fit(X,y)

predictions  =  model.predict(X_test)
score        =  model.score(X, y)
betacoef     =  model.coef_

# %%
score
# Out:
# 0.8352790179874754

# %%
test['SalePrice'] = predictions

# %%
pd.DataFrame(test['SalePrice'], index = test['Id'])
# Out:
#           SalePrice
# Id
# 2658            NaN
# 2718            NaN
# 2414            NaN
# 1989            NaN
# 625   135532.869059
# 333   145188.314813
# 1327            NaN
# 858   101645.755846
# 95    124422.602990
# 1568            NaN
# 2482            NaN
# 1364            NaN
# 2584            NaN
# 818    89824.645814
# 2673            NaN
# 2089            NaN
# 1297            NaN
# 790   158654.184772
# 2616            NaN
# 720   233752.169292
# 222   147364.947524
# 557   131311.205387
# 1148            NaN
# 2766            NaN
# 534   193841.998621
# 1452            NaN
# 630   147269.861455
# 2648            NaN
# 125   138344.011611
# 1904            NaN
# ...             ...
# 933             NaN
# 2784            NaN
# 972             NaN
# 599   111954.409681
# 2614            NaN
# 2582            NaN
# 1409            NaN
# 175   208413.022100
# 352   168964.197003
# 976             NaN
# 2134            NaN
# 984             NaN
# 2396            NaN
# 1673            NaN
# 404   285337.914716
# 607   117694.736012
# 814   162353.411803
# 868   224074.412405
# 2271            NaN
# 1633            NaN
# 337    81025.200272
# 2765            NaN
# 1746            NaN
# 368   187727.577710
# 2806            NaN
# 1662            NaN
# 1234            NaN
# 1373            NaN
# 1672            NaN
# 1939            NaN
#
# [879 rows x 1 columns]

# %%
#submit.to_csv('submission.csv')

# %%
##OVERFIT TEST

from sklearn.preprocessing import PolynomialFeatures
X = df[features]
pf = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
pf = pf.fit(X)
Xoverfit = pf.transform(X)
Xoverfit.shape
# Out:
# (2051, 171)

# %%
from sklearn.preprocessing import PolynomialFeatures
X = test[features]
pf = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
pf = pf.fit(X_test)
Xoverfit_test = pf.transform(X)
Xoverfit_test.shape
# Out:
# (879, 171)

# %%
X_test.shape
# Out:
# (879, 18)

# %%
lm = linear_model.LinearRegression()
target = df['SalePrice']
y = target
model = lm.fit(Xoverfit,y)

predictions_overfit  =  model.predict(Xoverfit_test)
score_overfit      =  model.score(Xoverfit, y)
betacoef_overfit     =  model.coef_

# %%
mse = mean_squared_error(y,predictions_overfit)
print('RMSE:',np.sqrt(mse))
print('R2:',score_overfit)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-02f04382dde4> in <module>()
# ----> 1 mse = mean_squared_error(y,predictions_overfit)
#       2 print('RMSE:',np.sqrt(mse))
#       3 print('R2:',score_overfit)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     236     """
#     237     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 238         y_true, y_pred, multioutput)
#     239     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     240                                weights=sample_weight)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [2051, 879]

# %%
score_overfit
# Out:
# 0.9122260095855894

# %%
## Normalizing Predicitors

# %%
len(predictions_overfit)
# Out:
# 879

# %%
submit = test[['Id','SalePrice']]

# %%
submit
# Out:
#        Id      SalePrice
# 0    2658  142287.906525
# 1    2718  195135.203435
# 2    2414  197054.121246
# 3    1989  124481.492097
# 4     625  180469.711476
# 5     333  107714.473106
# 6    1327  125028.310718
# 7     858  145124.879437
# 8      95  201807.902169
# 9    1568  180257.645997
# 10   2482  161506.017253
# 11   1364  123375.131656
# 12   2584  157231.949617
# 13    818  287093.870044
# 14   2673  163897.520277
# 15   2089  140656.464315
# 16   1297  170734.920972
# 17    790  116471.207186
# 18   2616  204089.881407
# 19    720  203869.573040
# 20    222  147587.069588
# 21    557  121896.397358
# 22   1148  203857.469024
# 23   2766  160090.991171
# 24    534  189899.434892
# 25   1452  115083.449532
# 26    630  154305.058204
# 27   2648  122992.693793
# 28    125  128651.706546
# 29   1904   50488.613520
# ..    ...            ...
# 849   933  143688.543424
# 850  2784  158451.771453
# 851   972  162891.609581
# 852   599  164409.346177
# 853  2614  109197.297517
# 854  2582  162103.840037
# 855  1409  149506.547023
# 856   175  103346.523541
# 857   352  235107.369048
# 858   976  101645.755846
# 859  2134  194954.202319
# 860   984  108809.454936
# 861  2396  389564.634834
# 862  1673  147030.673697
# 863   404  135700.735989
# 864   607  172131.868359
# 865   814  179838.815439
# 866   868  199515.246187
# 867  2271  198399.755672
# 868  1633  224074.412405
# 869   337  207449.459813
# 870  2765  156192.175468
# 871  1746  222729.629347
# 872   368  304887.543962
# 873  2806  196358.062405
# 874  1662  187421.612399
# 875  1234  199179.883378
# 876  1373  142323.524496
# 877  1672  112985.556110
# 878  1939  135301.638555
#
# [879 rows x 2 columns]

# %%
submit.to_csv('Submission_2.csv')

# %%
pd.DataFrame(test['SalePrice'],index = test['Id'])
# Out:
#           SalePrice
# Id
# 2658            NaN
# 2718            NaN
# 2414            NaN
# 1989            NaN
# 625   139437.784129
# 333   139767.778269
# 1327            NaN
# 858    92097.627879
# 95    125787.905222
# 1568            NaN
# 2482            NaN
# 1364            NaN
# 2584            NaN
# 818   113226.936472
# 2673            NaN
# 2089            NaN
# 1297            NaN
# 790   168206.332957
# 2616            NaN
# 720   222155.342722
# 222   163225.747019
# 557   137516.504832
# 1148            NaN
# 2766            NaN
# 534   192303.233347
# 1452            NaN
# 630   147846.168894
# 2648            NaN
# 125   129436.780222
# 1904            NaN
# ...             ...
# 933             NaN
# 2784            NaN
# 972             NaN
# 599   120939.344675
# 2614            NaN
# 2582            NaN
# 1409            NaN
# 175   207810.176707
# 352   152663.393504
# 976             NaN
# 2134            NaN
# 984             NaN
# 2396            NaN
# 1673            NaN
# 404   292054.762644
# 607   127753.682566
# 814   177233.090769
# 868   228509.301707
# 2271            NaN
# 1633            NaN
# 337    97549.516550
# 2765            NaN
# 1746            NaN
# 368   167077.881785
# 2806            NaN
# 1662            NaN
# 1234            NaN
# 1373            NaN
# 1672            NaN
# 1939            NaN
#
# [879 rows x 1 columns]

# %%
print(r2_score(y,predictions))
print(mean_squared_error(y,predictions))

# %%
lr_model = LinearRegression()
lr_cv_mean_mse = -cross_val_score(lr_model, X, y, cv=5, scoring='neg_mean_squared_error').mean()
lr_cv_mean_r2 = cross_val_score(lr_model, X, y, cv=5, scoring='r2').mean()
lr_cv_mean_mse, lr_cv_mean_r2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3484118a5b78> in <module>()
#       1 lr_model = LinearRegression()
# ----> 2 lr_cv_mean_mse = -cross_val_score(lr_model, X, y, cv=5, scoring='neg_mean_squared_error').mean()
#       3 lr_cv_mean_r2 = cross_val_score(lr_model, X, y, cv=5, scoring='r2').mean()
#       4 lr_cv_mean_mse, lr_cv_mean_r2
#
# NameError: name 'X' is not defined

# %%
from sklearn.linear_model import Lasso, LassoCV

# %%
l_alphas = np.logspace(0,4,30)
lasso_model = LassoCV(alphas=l_alphas, cv=5,)
lasso_model = lasso_model.fit(X, y)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
lasso_optimal_alpha = lasso_model.alpha_
lasso_optimal_alpha
# Out:
# 4.893900918477494

# %%
lasso_model = Lasso(alpha=lasso_optimal_alpha)

# %%
lasso_model.fit(X,y)
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Lasso(alpha=0.49985, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_mse = -cross_val_score(lasso_model, X, y, cv=5, scoring='neg_mean_squared_error').mean()
# Out:
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\tbaca\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
np.sqrt(lasso_mse)
# Out:
# 34047.640861852466
